# %% [markdown]
# ## Exercise 11.1.
# ### This exercise creates a module named zoo with a function called hours() that prints the zoo's business hours.

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## Exercise 11.2
#
# This exercise imports the zoo module using an alias and calls the hours() function.

# %%
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## Exercise 16.8
#
# This exercise uses SQLAlchemy to connect to the books.db SQLite database and select the title column from the book table in alphabetical order.

# %%
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///books.db")

with engine.connect() as connection:
    result = connection.execute(
        text("SELECT title FROM book ORDER BY title ASC")
    )
    
    for row in result:
        print(row[0])
# Out:
# 1984
# Brave New World
# Moby Dick
# The Great Gatsby

# %%
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///books.db")

with engine.connect() as connection:
    # Remove all existing rows
    connection.execute(text("DELETE FROM book"))
    
    # Insert fresh data once
    connection.execute(text("""
        INSERT INTO book (title) VALUES
        ('The Great Gatsby'),
        ('1984'),
        ('Brave New World'),
        ('Moby Dick')
    """))
    
    connection.commit()
